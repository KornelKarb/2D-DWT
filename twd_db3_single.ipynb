# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from keras import datasets
from sklearn import metrics
from sklearn.model_selection import train_test_split

import pywt
import pywt.data
from keras.datasets import mnist
import time

# %%
from sklearn.naive_bayes import GaussianNB #NaiveBayes
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis #LDA, QDA
from sklearn.neighbors import NearestCentroid #NM
from sklearn.neighbors import KNeighborsClassifier #kNN
from sklearn.svm import SVC #SVM

# %%
classifiers = [
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    NearestCentroid(),
    KNeighborsClassifier(n_neighbors=1),
    KNeighborsClassifier(n_neighbors=3, algorithm='brute'),
    KNeighborsClassifier(n_neighbors=5),
    KNeighborsClassifier(n_neighbors=7),
    SVC()  
]

title = [
    'Naiwny Bayes',
    'LDA',
    'Nearest Mean',
    'kNN1',
    'kNN3',
    'kNN5',
    'kNN7',
    'SVM'
]

wavelet_type = 'db3'

# %%
(xtrain_mnist, y_train_mnist),(dataset, label) = mnist.load_data()

# %%
dataset_reshape = np.reshape(dataset, (dataset.shape[0], -1))
label_reshape = np.array(label, dtype=int)



xTest_mnist = np.reshape(xtrain_mnist, (xtrain_mnist.shape[0], -1))
y_test_mnist = np.array(y_train_mnist, dtype=int)

# %%
def fit_model(name, sample, data,label):

    X_train, X_test, y_train, y_test = train_test_split(
        data, label, test_size=sample, shuffle=True
    )
    name.fit(X_train,y_train)
    predicted = name.predict(X_test)

    return predicted, X_test, y_test

# %%
images_haar_LL = np.empty(shape=(10000,16,16))
images_haar_LH = np.empty(shape=(10000,16,16))
images_haar_HL = np.empty(shape=(10000,16,16))
images_haar_HH = np.empty(shape=(10000,16,16))
for i in range(len(dataset)):
    db_decompo = pywt.dwt2(dataset[i], wavelet_type)
    LL, (LH, HL, HH) = db_decompo
    images_haar_LL[i] = LL
    images_haar_LH[i] = LH
    images_haar_HL[i] = HL
    images_haar_HH[i] = HH

# %%
images_haar_LL_reshape = np.reshape(images_haar_LL, (images_haar_LL.shape[0], -1))
images_haar_LH_reshape = np.reshape(images_haar_LH, (images_haar_LH.shape[0], -1))
images_haar_HL_reshape = np.reshape(images_haar_HL, (images_haar_HL.shape[0], -1))
images_haar_HH_reshape = np.reshape(images_haar_HH, (images_haar_HH.shape[0], -1))

# %%
decompo_list = [images_haar_LL_reshape, images_haar_LH_reshape, images_haar_HL_reshape,images_haar_HH_reshape]
type_name = ['LL','LH','HL','HH']

# %%
test_sample = 0.4
for index, k in enumerate(decompo_list):
  print(type_name[index])
  for idx, i in enumerate(classifiers):
    print('Model: ',i)
    sumAcc = 0
    meanAcc = 0
    start_time = time.time() 
    for j in range(10):
        model = i
        predicted, X_test, y_test = fit_model(i,test_sample, k, label)
        sumAcc += metrics.accuracy_score(y_test, predicted)
    meanAcc = sumAcc/10
    end_time = time.time()  # Koniec mierzenia czasu
    elapsed_time = end_time - start_time
    print('Średnia dokłądności: ',meanAcc)
    print('Czas obliczania: ', elapsed_time, ' sekund')
# Out:
# LL
# Model:  GaussianNB()
# Średnia dokłądności:  0.529525
# Czas obliczania:  1.6754467487335205  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.864625
# Czas obliczania:  3.648193359375  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.819275
# Czas obliczania:  0.2724192142486572  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.952375
# Czas obliczania:  4.4233314990997314  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.9506
# Czas obliczania:  4.458291053771973  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.9508749999999999
# Czas obliczania:  4.483487606048584  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.946875
# Czas obliczania:  4.7365641593933105  sekund
# Model:  SVC()
# Średnia dokłądności:  0.960875
# Czas obliczania:  37.293521881103516  sekund
# LH
# Model:  GaussianNB()
# Średnia dokłądności:  0.513175
# Czas obliczania:  1.6604390144348145  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.6205
# Czas obliczania:  3.4729058742523193  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.46475
# Czas obliczania:  0.27065181732177734  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.614675
# Czas obliczania:  4.360933303833008  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.5579750000000001
# Czas obliczania:  4.176772594451904  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.5276
# Czas obliczania:  4.332496404647827  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.501475
# Czas obliczania:  4.7141313552856445  sekund
# Model:  SVC()
# Średnia dokłądności:  0.804775
# Czas obliczania:  93.25387406349182  sekund
# HL
# Model:  GaussianNB()
# Średnia dokłądności:  0.5050250000000001
# Czas obliczania:  1.548271894454956  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.5596
# Czas obliczania:  3.48602032661438  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.385925
# Czas obliczania:  0.25379300117492676  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.6476500000000001
# Czas obliczania:  4.231592416763306  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.6359999999999999
# Czas obliczania:  4.528783559799194  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.63055
# Czas obliczania:  4.5942559242248535  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.6269000000000001
# Czas obliczania:  4.639533996582031  sekund
# Model:  SVC()
# Średnia dokłądności:  0.7502
# Czas obliczania:  114.66070914268494  sekund
# HH
# Model:  GaussianNB()
# Średnia dokłądności:  0.46367499999999995
# Czas obliczania:  1.441683053970337  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.310625
# Czas obliczania:  3.445549964904785  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.1587
# Czas obliczania:  0.2302570343017578  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.231875
# Czas obliczania:  4.431901931762695  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.17550000000000002
# Czas obliczania:  4.315813779830933  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.15555000000000002
# Czas obliczania:  4.8078413009643555  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.1469
# Czas obliczania:  4.4812211990356445  sekund
# Model:  SVC()
# Średnia dokłądności:  0.51815
# Czas obliczania:  136.62856101989746  sekund

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 8))

for idx, i in enumerate(classifiers):
    predicted, X_test, y_test = fit_model(i,test_sample, images_haar_HH_reshape, label)
    disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
    disp.plot(ax=axes[idx // 4, idx % 4])
    axes[idx // 4, idx % 4].set_title('Klasyfikator: ' + title[idx])

    # print(f"Confusion matrix:\n{disp.confusion_matrix}")
fig.suptitle("Macierz pomyłek")
# plt.tight_layout()
plt.show()

# %% [markdown]
# Haar Lvl 2

# %%
images_haar_LL2 = np.empty(shape=(10000,10,10))
images_haar_LH2 = np.empty(shape=(10000,10,10))
images_haar_HL2 = np.empty(shape=(10000,10,10))
images_haar_HH2 = np.empty(shape=(10000,10,10))


for i in range(len(images_haar_LL)):
    db_decompo_2 = pywt.dwt2(images_haar_LL[i], wavelet_type)
    LL, (LH, HL, HH) = db_decompo_2
    images_haar_LL2[i] = LL
    images_haar_LH2[i] = LH
    images_haar_HL2[i] = HL
    images_haar_HH2[i] = HH

# %%
images_haar_LL2_reshape = np.reshape(images_haar_LL2, (images_haar_LL2.shape[0], -1))
images_haar_LH2_reshape = np.reshape(images_haar_LH2, (images_haar_LH2.shape[0], -1))
images_haar_HL2_reshape = np.reshape(images_haar_HL2, (images_haar_HL2.shape[0], -1))
images_haar_HH2_reshape = np.reshape(images_haar_HH2, (images_haar_HH2.shape[0], -1))

# %%
decompo_list = [images_haar_LL2_reshape, images_haar_LH2_reshape, images_haar_HL2_reshape,images_haar_HH2_reshape]
type_name = ['LL2','LH2','HL2','HH2']

# %%
test_sample = 0.4
for index, k in enumerate(decompo_list):
  print(type_name[index])
  for idx, i in enumerate(classifiers):
    print('Model: ',i)
    sumAcc = 0
    meanAcc = 0
    start_time = time.time() 
    for j in range(10):
        model = i
        predicted, X_test, y_test = fit_model(i,test_sample, k, label)
        sumAcc += metrics.accuracy_score(y_test, predicted)
    meanAcc = sumAcc/10
    end_time = time.time()  # Koniec mierzenia czasu
    elapsed_time = end_time - start_time
    print('Średnia dokłądności: ',meanAcc)
    print('Czas obliczania: ', elapsed_time, ' sekund')
# Out:
# LL2
# Model:  GaussianNB()
# Średnia dokłądności:  0.5794750000000001
# Czas obliczania:  0.5211787223815918  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.8505499999999999
# Czas obliczania:  1.0904433727264404  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.7893500000000001
# Czas obliczania:  0.10570430755615234  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.9344999999999999
# Czas obliczania:  3.085704803466797  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.93645
# Czas obliczania:  3.0634467601776123  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.9357249999999999
# Czas obliczania:  3.179875135421753  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.936225
# Czas obliczania:  3.1521472930908203  sekund
# Model:  SVC()
# Średnia dokłądności:  0.9432499999999999
# Czas obliczania:  23.811910390853882  sekund
# LH2
# Model:  GaussianNB()
# Średnia dokłądności:  0.5670999999999999
# Czas obliczania:  0.5187816619873047  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.71835
# Czas obliczania:  1.0900256633758545  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.627375
# Czas obliczania:  0.10006427764892578  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.8257999999999999
# Czas obliczania:  3.0648369789123535  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.8182500000000001
# Czas obliczania:  3.0334770679473877  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.814875
# Czas obliczania:  3.355591297149658  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.808175
# Czas obliczania:  3.18241024017334  sekund
# Model:  SVC()
# Średnia dokłądności:  0.8822749999999999
# Czas obliczania:  37.85728311538696  sekund
# HL2
# Model:  GaussianNB()
# Średnia dokłądności:  0.5496000000000001
# Czas obliczania:  0.6230118274688721  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.7108499999999999
# Czas obliczania:  1.4315569400787354  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.47932499999999995
# Czas obliczania:  0.18847131729125977  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.806
# Czas obliczania:  3.376030445098877  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.798125
# Czas obliczania:  3.2656443119049072  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.799825
# Czas obliczania:  3.302072525024414  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.7967
# Czas obliczania:  3.3840231895446777  sekund
# Model:  SVC()
# Średnia dokłądności:  0.857925
# Czas obliczania:  48.31202220916748  sekund
# HH2
# Model:  GaussianNB()
# Średnia dokłądności:  0.5083000000000001
# Czas obliczania:  0.53316330909729  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.5744750000000001
# Czas obliczania:  1.1398296356201172  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.2448
# Czas obliczania:  0.10102391242980957  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.58565
# Czas obliczania:  3.510258436203003  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.569925
# Czas obliczania:  3.5016820430755615  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.564025
# Czas obliczania:  3.203202486038208  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.5592500000000001
# Czas obliczania:  3.413308620452881  sekund
# Model:  SVC()
# Średnia dokłądności:  0.72055
# Czas obliczania:  69.03450202941895  sekund

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 8))

for idx, i in enumerate(classifiers):
    predicted, X_test, y_test = fit_model(i,test_sample, images_haar_HH2_reshape, label)
    disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
    disp.plot(ax=axes[idx // 4, idx % 4])
    axes[idx // 4, idx % 4].set_title('Klasyfikator: ' + title[idx])

    # print(f"Confusion matrix:\n{disp.confusion_matrix}")
fig.suptitle("Macierz pomyłek")
# plt.tight_layout()
plt.show()

# %%
images_haar_LL3 = np.empty(shape=(10000,7,7))
images_haar_LH3 = np.empty(shape=(10000,7,7))
images_haar_HL3 = np.empty(shape=(10000,7,7))
images_haar_HH3 = np.empty(shape=(10000,7,7))

# images_haar_LL = np.empty(shape=(10000,16,16))
# images_haar_LH = np.empty(shape=(10000,16,16))
# images_haar_HL = np.empty(shape=(10000,16,16))
# images_haar_HH = np.empty(shape=(10000,16,16))

for i in range(len(images_haar_LL2)):
    db_decompo_2 = pywt.dwt2(images_haar_LL2[i], wavelet_type)
    LL, (LH, HL, HH) = db_decompo_2
    images_haar_LL3[i] = LL
    images_haar_LH3[i] = LH
    images_haar_HL3[i] = HL
    images_haar_HH3[i] = HH

# %%
images_haar_LL3_reshape = np.reshape(images_haar_LL3, (images_haar_LL3.shape[0], -1))
images_haar_LH3_reshape = np.reshape(images_haar_LH3, (images_haar_LH3.shape[0], -1))
images_haar_HL3_reshape = np.reshape(images_haar_HL3, (images_haar_HL3.shape[0], -1))
images_haar_HH3_reshape = np.reshape(images_haar_HH3, (images_haar_HH3.shape[0], -1))

# %%
decompo_list = [images_haar_LL3_reshape, images_haar_LH3_reshape, images_haar_HL3_reshape,images_haar_HH3_reshape]
type_name = ['LL3','LH3','HL3','HH3']

# %%
test_sample = 0.4
for index, k in enumerate(decompo_list):
  print(type_name[index])
  for idx, i in enumerate(classifiers):
    print('Model: ',i)
    sumAcc = 0
    meanAcc = 0
    start_time = time.time() 
    for j in range(10):
        model = i
        predicted, X_test, y_test = fit_model(i,test_sample, k, label)
        sumAcc += metrics.accuracy_score(y_test, predicted)
    meanAcc = sumAcc/10
    end_time = time.time()  # Koniec mierzenia czasu
    elapsed_time = end_time - start_time
    print('Średnia dokłądności: ',meanAcc)
    print('Czas obliczania: ', elapsed_time, ' sekund')
# Out:
# LL3
# Model:  GaussianNB()
# Średnia dokłądności:  0.5529499999999999
# Czas obliczania:  0.28139519691467285  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.7889750000000001
# Czas obliczania:  0.5421285629272461  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.559825
# Czas obliczania:  0.06936311721801758  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.7351499999999999
# Czas obliczania:  2.729173421859741  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.7529
# Czas obliczania:  2.74160099029541  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.7591
# Czas obliczania:  2.750410556793213  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.7673
# Czas obliczania:  2.805281162261963  sekund
# Model:  SVC()
# Średnia dokłądności:  0.7949999999999999
# Czas obliczania:  35.030762672424316  sekund
# LH3
# Model:  GaussianNB()
# Średnia dokłądności:  0.5975250000000001
# Czas obliczania:  0.2625131607055664  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.8180249999999999
# Czas obliczania:  0.5332357883453369  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.6501
# Czas obliczania:  0.06419992446899414  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.8266249999999999
# Czas obliczania:  2.6929514408111572  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.82575
# Czas obliczania:  2.815784454345703  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.8309749999999999
# Czas obliczania:  2.758169174194336  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.8311999999999999
# Czas obliczania:  2.8174102306365967  sekund
# Model:  SVC()
# Średnia dokłądności:  0.8823000000000001
# Czas obliczania:  25.188138484954834  sekund
# HL3
# Model:  GaussianNB()
# Średnia dokłądności:  0.5738
# Czas obliczania:  0.27945399284362793  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.813925
# Czas obliczania:  0.5723779201507568  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.519075
# Czas obliczania:  0.0647728443145752  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.796675
# Czas obliczania:  2.883075714111328  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.8027749999999999
# Czas obliczania:  2.720160722732544  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.808675
# Czas obliczania:  2.7595667839050293  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.810225
# Czas obliczania:  2.7833850383758545  sekund
# Model:  SVC()
# Średnia dokłądności:  0.8565250000000001
# Czas obliczania:  32.19643044471741  sekund
# HH3
# Model:  GaussianNB()
# Średnia dokłądności:  0.57135
# Czas obliczania:  0.28370022773742676  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.8503000000000001
# Czas obliczania:  0.6746695041656494  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.486775
# Czas obliczania:  0.07354903221130371  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.771425
# Czas obliczania:  3.1966309547424316  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.7742
# Czas obliczania:  2.990549087524414  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.779525
# Czas obliczania:  3.32810378074646  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.7743250000000002
# Czas obliczania:  2.973356008529663  sekund
# Model:  SVC()
# Średnia dokłądności:  0.852225
# Czas obliczania:  34.516318798065186  sekund

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 8))

for idx, i in enumerate(classifiers):
    predicted, X_test, y_test = fit_model(i,test_sample, images_haar_HH3_reshape, label)
    disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
    disp.plot(ax=axes[idx // 4, idx % 4])
    axes[idx // 4, idx % 4].set_title('Klasyfikator: ' + title[idx])

    # print(f"Confusion matrix:\n{disp.confusion_matrix}")
fig.suptitle("Macierz pomyłek")
# plt.tight_layout()
plt.show()
