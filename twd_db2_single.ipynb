# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from keras import datasets
from sklearn import metrics
from sklearn.model_selection import train_test_split

import pywt
import pywt.data
from keras.datasets import mnist
import time

# %%
from sklearn.naive_bayes import GaussianNB #NaiveBayes
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis #LDA, QDA
from sklearn.neighbors import NearestCentroid #NM
from sklearn.neighbors import KNeighborsClassifier #kNN
from sklearn.svm import SVC #SVM

# %%
classifiers = [
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    NearestCentroid(),
    KNeighborsClassifier(n_neighbors=1),
    KNeighborsClassifier(n_neighbors=3, algorithm='brute'),
    KNeighborsClassifier(n_neighbors=5),
    KNeighborsClassifier(n_neighbors=7),
    SVC()  
]

title = [
    'Naiwny Bayes',
    'LDA',
    'Nearest Mean',
    'kNN1',
    'kNN3',
    'kNN5',
    'kNN7',
    'SVM'
]

wavelet_type = 'db2'

# %%
(xtrain_mnist, y_train_mnist),(dataset, label) = mnist.load_data()

# %%
dataset_reshape = np.reshape(dataset, (dataset.shape[0], -1))
label_reshape = np.array(label, dtype=int)



xTest_mnist = np.reshape(xtrain_mnist, (xtrain_mnist.shape[0], -1))
y_test_mnist = np.array(y_train_mnist, dtype=int)

# %%
def fit_model(name, sample, data,label):

    X_train, X_test, y_train, y_test = train_test_split(
        data, label, test_size=sample, shuffle=True
    )
    name.fit(X_train,y_train)
    predicted = name.predict(X_test)

    return predicted, X_test, y_test

# %%
images_haar_LL = np.empty(shape=(10000,15,15))
images_haar_LH = np.empty(shape=(10000,15,15))
images_haar_HL = np.empty(shape=(10000,15,15))
images_haar_HH = np.empty(shape=(10000,15,15))

# images_haar_LL = np.empty(shape=(10000,16,16))
# images_haar_LH = np.empty(shape=(10000,16,16))
# images_haar_HL = np.empty(shape=(10000,16,16))
# images_haar_HH = np.empty(shape=(10000,16,16))
for i in range(len(dataset)):
    db_decompo = pywt.dwt2(dataset[i], wavelet_type)
    LL, (LH, HL, HH) = db_decompo
    images_haar_LL[i] = LL
    images_haar_LH[i] = LH
    images_haar_HL[i] = HL
    images_haar_HH[i] = HH

# %%
images_haar_LL_reshape = np.reshape(images_haar_LL, (images_haar_LL.shape[0], -1))
images_haar_LH_reshape = np.reshape(images_haar_LH, (images_haar_LH.shape[0], -1))
images_haar_HL_reshape = np.reshape(images_haar_HL, (images_haar_HL.shape[0], -1))
images_haar_HH_reshape = np.reshape(images_haar_HH, (images_haar_HH.shape[0], -1))

# %%
decompo_list = [images_haar_LL_reshape, images_haar_LH_reshape, images_haar_HL_reshape,images_haar_HH_reshape]
type_name = ['LL','LH','HL','HH']

# %%
test_sample = 0.4
for index, k in enumerate(decompo_list):
  print(type_name[index])
  for idx, i in enumerate(classifiers):
    print('Model: ',i)
    sumAcc = 0
    meanAcc = 0
    start_time = time.time() 
    for j in range(10):
        model = i
        predicted, X_test, y_test = fit_model(i,test_sample, k, label)
        sumAcc += metrics.accuracy_score(y_test, predicted)
    meanAcc = sumAcc/10
    end_time = time.time()  # Koniec mierzenia czasu
    elapsed_time = end_time - start_time
    print('Średnia dokłądności: ',meanAcc)
    print('Czas obliczania: ', elapsed_time, ' sekund')
# Out:
# LL
# Model:  GaussianNB()
# Średnia dokłądności:  0.6032999999999998
# Czas obliczania:  1.4713914394378662  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.871025
# Czas obliczania:  2.9540765285491943  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.817825
# Czas obliczania:  0.24175739288330078  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.9533750000000001
# Czas obliczania:  4.29631495475769  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.9524250000000001
# Czas obliczania:  4.355708122253418  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.9522
# Czas obliczania:  4.524559736251831  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.95015
# Czas obliczania:  4.704243898391724  sekund
# Model:  SVC()
# Średnia dokłądności:  0.9615500000000001
# Czas obliczania:  34.83652067184448  sekund
# LH
# Model:  GaussianNB()
# Średnia dokłądności:  0.5460749999999999
# Czas obliczania:  1.3419320583343506  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.6900999999999999
# Czas obliczania:  3.0229315757751465  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.541525
# Czas obliczania:  0.23006463050842285  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.6854750000000001
# Czas obliczania:  4.079094409942627  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.63255
# Czas obliczania:  4.447349786758423  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.603775
# Czas obliczania:  4.695579290390015  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.5779249999999999
# Czas obliczania:  4.870422840118408  sekund
# Model:  SVC()
# Średnia dokłądności:  0.856075
# Czas obliczania:  78.80814361572266  sekund
# HL
# Model:  GaussianNB()
# Średnia dokłądności:  0.528275
# Czas obliczania:  1.4549968242645264  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.6514
# Czas obliczania:  2.9541192054748535  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.4685499999999999
# Czas obliczania:  0.24001359939575195  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.71375
# Czas obliczania:  4.330236911773682  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.704375
# Czas obliczania:  4.397543430328369  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.702175
# Czas obliczania:  4.240736722946167  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.6967749999999999
# Czas obliczania:  4.249249696731567  sekund
# Model:  SVC()
# Średnia dokłądności:  0.8206
# Czas obliczania:  95.28915143013  sekund
# HH
# Model:  GaussianNB()
# Średnia dokłądności:  0.473075
# Czas obliczania:  1.4572844505310059  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.3351
# Czas obliczania:  2.9470582008361816  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.199125
# Czas obliczania:  0.26172852516174316  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.24584999999999999
# Czas obliczania:  4.384960651397705  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.18872499999999998
# Czas obliczania:  4.0066304206848145  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.16522499999999998
# Czas obliczania:  4.413072109222412  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.157275
# Czas obliczania:  4.200003385543823  sekund
# Model:  SVC()
# Średnia dokłądności:  0.53615
# Czas obliczania:  128.02225065231323  sekund

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 8))

for idx, i in enumerate(classifiers):
    predicted, X_test, y_test = fit_model(i,test_sample, images_haar_HH_reshape, label)
    disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
    disp.plot(ax=axes[idx // 4, idx % 4])
    axes[idx // 4, idx % 4].set_title('Klasyfikator: ' + title[idx])

# print(f"Confusion matrix:\n{disp.confusion_matrix}")
fig.suptitle("Macierz pomyłek")
# plt.tight_layout()
plt.show()

# %% [markdown]
# Haar Lvl 2

# %%
images_haar_LL2 = np.empty(shape=(10000,9,9))
images_haar_LH2 = np.empty(shape=(10000,9,9))
images_haar_HL2 = np.empty(shape=(10000,9,9))
images_haar_HH2 = np.empty(shape=(10000,9,9))

# images_haar_LL = np.empty(shape=(10000,16,16))
# images_haar_LH = np.empty(shape=(10000,16,16))
# images_haar_HL = np.empty(shape=(10000,16,16))
# images_haar_HH = np.empty(shape=(10000,16,16))

for i in range(len(images_haar_LL)):
    db_decompo_2 = pywt.dwt2(images_haar_LL[i], wavelet_type)
    LL, (LH, HL, HH) = db_decompo_2
    images_haar_LL2[i] = LL
    images_haar_LH2[i] = LH
    images_haar_HL2[i] = HL
    images_haar_HH2[i] = HH

# %%
images_haar_LL2_reshape = np.reshape(images_haar_LL2, (images_haar_LL2.shape[0], -1))
images_haar_LH2_reshape = np.reshape(images_haar_LH2, (images_haar_LH2.shape[0], -1))
images_haar_HL2_reshape = np.reshape(images_haar_HL2, (images_haar_HL2.shape[0], -1))
images_haar_HH2_reshape = np.reshape(images_haar_HH2, (images_haar_HH2.shape[0], -1))

# %%
decompo_list = [images_haar_LL2_reshape, images_haar_LH2_reshape, images_haar_HL2_reshape,images_haar_HH2_reshape]
type_name = ['LL2','LH2','HL2','HH2']

# %%
test_sample = 0.4
for index, k in enumerate(decompo_list):
  print(type_name[index])
  for idx, i in enumerate(classifiers):
    print('Model: ',i)
    sumAcc = 0
    meanAcc = 0
    start_time = time.time() 
    for j in range(10):
        model = i
        predicted, X_test, y_test = fit_model(i,test_sample, k, label)
        sumAcc += metrics.accuracy_score(y_test, predicted)
    meanAcc = sumAcc/10
    end_time = time.time()  # Koniec mierzenia czasu
    elapsed_time = end_time - start_time
    print('Średnia dokłądności: ',meanAcc)
    print('Czas obliczania: ', elapsed_time, ' sekund')
# Out:
# LL2
# Model:  GaussianNB()
# Średnia dokłądności:  0.557
# Czas obliczania:  0.44758129119873047  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.8477750000000001
# Czas obliczania:  0.9161901473999023  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.780025
# Czas obliczania:  0.09217667579650879  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.92865
# Czas obliczania:  3.021552801132202  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.9321499999999998
# Czas obliczania:  3.113400936126709  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.9337249999999999
# Czas obliczania:  3.1331608295440674  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.929475
# Czas obliczania:  3.2040441036224365  sekund
# Model:  SVC()
# Średnia dokłądności:  0.94285
# Czas obliczania:  22.36786723136902  sekund
# LH2
# Model:  GaussianNB()
# Średnia dokłądności:  0.5472999999999999
# Czas obliczania:  0.411588191986084  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.724625
# Czas obliczania:  0.8695013523101807  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.6245
# Czas obliczania:  0.08194756507873535  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.8193999999999999
# Czas obliczania:  2.965543031692505  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.8177999999999999
# Czas obliczania:  3.4123740196228027  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.8143
# Czas obliczania:  2.980384111404419  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.8101500000000001
# Czas obliczania:  3.0526723861694336  sekund
# Model:  SVC()
# Średnia dokłądności:  0.883025
# Czas obliczania:  34.74446249008179  sekund
# HL2
# Model:  GaussianNB()
# Średnia dokłądności:  0.53965
# Czas obliczania:  0.41231751441955566  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.6721000000000001
# Czas obliczania:  0.8689889907836914  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.48497499999999993
# Czas obliczania:  0.08309507369995117  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.8031250000000002
# Czas obliczania:  2.9625606536865234  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.8045500000000001
# Czas obliczania:  2.9570813179016113  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.8022
# Czas obliczania:  2.9465808868408203  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.7968
# Czas obliczania:  2.9543943405151367  sekund
# Model:  SVC()
# Średnia dokłądności:  0.8595
# Czas obliczania:  41.67431449890137  sekund
# HH2
# Model:  GaussianNB()
# Średnia dokłądności:  0.4949
# Czas obliczania:  0.4240896701812744  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.585825
# Czas obliczania:  0.9046597480773926  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.34327500000000005
# Czas obliczania:  0.08876657485961914  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.610375
# Czas obliczania:  3.0429399013519287  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.592725
# Czas obliczania:  2.9550516605377197  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.5924750000000001
# Czas obliczania:  2.952599287033081  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.5869
# Czas obliczania:  2.947291851043701  sekund
# Model:  SVC()
# Średnia dokłądności:  0.7277250000000001
# Czas obliczania:  59.424840688705444  sekund

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 8))

for idx, i in enumerate(classifiers):
    predicted, X_test, y_test = fit_model(i,test_sample, images_haar_HH2_reshape, label)
    disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
    disp.plot(ax=axes[idx // 4, idx % 4])
    axes[idx // 4, idx % 4].set_title('Klasyfikator: ' + title[idx])

    # print(f"Confusion matrix:\n{disp.confusion_matrix}")
fig.suptitle("Macierz pomyłek")
# plt.tight_layout()
plt.show()

# %%
images_haar_LL3 = np.empty(shape=(10000,6,6))
images_haar_LH3 = np.empty(shape=(10000,6,6))
images_haar_HL3 = np.empty(shape=(10000,6,6))
images_haar_HH3 = np.empty(shape=(10000,6,6))

# images_haar_LL = np.empty(shape=(10000,16,16))
# images_haar_LH = np.empty(shape=(10000,16,16))
# images_haar_HL = np.empty(shape=(10000,16,16))
# images_haar_HH = np.empty(shape=(10000,16,16))

for i in range(len(images_haar_LL2)):
    db_decompo_2 = pywt.dwt2(images_haar_LL2[i], wavelet_type)
    LL, (LH, HL, HH) = db_decompo_2
    images_haar_LL3[i] = LL
    images_haar_LH3[i] = LH
    images_haar_HL3[i] = HL
    images_haar_HH3[i] = HH

# %%
images_haar_LL3_reshape = np.reshape(images_haar_LL3, (images_haar_LL3.shape[0], -1))
images_haar_LH3_reshape = np.reshape(images_haar_LH3, (images_haar_LH3.shape[0], -1))
images_haar_HL3_reshape = np.reshape(images_haar_HL3, (images_haar_HL3.shape[0], -1))
images_haar_HH3_reshape = np.reshape(images_haar_HH3, (images_haar_HH3.shape[0], -1))

# %%
decompo_list = [images_haar_LL3_reshape, images_haar_LH3_reshape, images_haar_HL3_reshape,images_haar_HH3_reshape]
type_name = ['LL3','LH3','HL3','HH3']

# %%
test_sample = 0.4
for index, k in enumerate(decompo_list):
  print(type_name[index])
  for idx, i in enumerate(classifiers):
    print('Model: ',i)
    sumAcc = 0
    meanAcc = 0
    start_time = time.time() 
    for j in range(10):
        model = i
        predicted, X_test, y_test = fit_model(i,test_sample, k, label)
        sumAcc += metrics.accuracy_score(y_test, predicted)
    meanAcc = sumAcc/10
    end_time = time.time()  # Koniec mierzenia czasu
    elapsed_time = end_time - start_time
    print('Średnia dokłądności: ',meanAcc)
    print('Czas obliczania: ', elapsed_time, ' sekund')
# Out:
# LL3
# Model:  GaussianNB()
# Średnia dokłądności:  0.625925
# Czas obliczania:  0.21497130393981934  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.767175
# Czas obliczania:  0.39821910858154297  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.6012
# Czas obliczania:  0.0571134090423584  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.774725
# Czas obliczania:  2.7329204082489014  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.7917500000000001
# Czas obliczania:  2.6881747245788574  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.7991250000000001
# Czas obliczania:  2.7062480449676514  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.80115
# Czas obliczania:  2.705099582672119  sekund
# Model:  SVC()
# Średnia dokłądności:  0.8275749999999998
# Czas obliczania:  30.875596284866333  sekund
# LH3
# Model:  GaussianNB()
# Średnia dokłądności:  0.66125
# Czas obliczania:  0.2111964225769043  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.8042250000000001
# Czas obliczania:  0.38480138778686523  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.6382000000000001
# Czas obliczania:  0.054944515228271484  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.8262000000000003
# Czas obliczania:  2.64953875541687  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.8281000000000001
# Czas obliczania:  2.705531358718872  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.8311249999999999
# Czas obliczania:  2.680426597595215  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.8302250000000001
# Czas obliczania:  2.7632548809051514  sekund
# Model:  SVC()
# Średnia dokłądności:  0.8906249999999998
# Czas obliczania:  24.50241255760193  sekund
# HL3
# Model:  GaussianNB()
# Średnia dokłądności:  0.6222749999999999
# Czas obliczania:  0.20442843437194824  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.78495
# Czas obliczania:  0.39328527450561523  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.5093
# Czas obliczania:  0.053878068923950195  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.7954
# Czas obliczania:  2.715508222579956  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.803225
# Czas obliczania:  2.749448299407959  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.8067
# Czas obliczania:  2.709242820739746  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.804375
# Czas obliczania:  2.7398016452789307  sekund
# Model:  SVC()
# Średnia dokłądności:  0.8599499999999999
# Czas obliczania:  30.11114501953125  sekund
# HH3
# Model:  GaussianNB()
# Średnia dokłądności:  0.5949749999999999
# Czas obliczania:  0.2394571304321289  sekund
# Model:  LinearDiscriminantAnalysis()
# Średnia dokłądności:  0.8227499999999999
# Czas obliczania:  0.5512092113494873  sekund
# Model:  NearestCentroid()
# Średnia dokłądności:  0.4892250000000001
# Czas obliczania:  0.08308029174804688  sekund
# Model:  KNeighborsClassifier(n_neighbors=1)
# Średnia dokłądności:  0.7608500000000001
# Czas obliczania:  3.077972650527954  sekund
# Model:  KNeighborsClassifier(algorithm='brute', n_neighbors=3)
# Średnia dokłądności:  0.761725
# Czas obliczania:  3.134639263153076  sekund
# Model:  KNeighborsClassifier()
# Średnia dokłądności:  0.7660750000000001
# Czas obliczania:  2.964247226715088  sekund
# Model:  KNeighborsClassifier(n_neighbors=7)
# Średnia dokłądności:  0.761575
# Czas obliczania:  2.8447062969207764  sekund
# Model:  SVC()
# Średnia dokłądności:  0.8503499999999999
# Czas obliczania:  33.376548528671265  sekund

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 8))

for idx, i in enumerate(classifiers):
    predicted, X_test, y_test = fit_model(i,test_sample, images_haar_HH3_reshape, label)
    disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
    disp.plot(ax=axes[idx // 4, idx % 4])
    axes[idx // 4, idx % 4].set_title('Klasyfikator: ' + title[idx])

    # print(f"Confusion matrix:\n{disp.confusion_matrix}")
fig.suptitle("Macierz pomyłek")
# plt.tight_layout()
plt.show()
